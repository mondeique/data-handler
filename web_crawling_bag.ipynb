# %% [markdown]
# # PARIS AND YOU web crawling

# %%
## 숄더/토트백

from bs4 import BeautifulSoup 
from urllib.request import urlopen 
import time

print("---------------------------------------------------------------------------")
print("숄더백 / 토트백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 2

img_url_list = []

print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://parisandyou.co.kr/category/%EC%88%84%EB%8D%94%ED%86%A0%ED%8A%B8%EB%B0%B1/26/'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "thumbnail" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//parisandyou.co.kr/'):
            img_url_list.append(url["src"])

                
while current_page <= 31:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://parisandyou.co.kr/category/%EC%88%84%EB%8D%94%ED%86%A0%ED%8A%B8%EB%B0%B1/26/' + '?page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//parisandyou.co.kr/'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)


shoulder_tote_img_url_list = list(set(img_url_list))

len(shoulder_tote_img_url_list)

## 퀼팅백

print("---------------------------------------------------------------------------")
print("퀼팅백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 2

img_url_list = []

print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://parisandyou.co.kr/category/%ED%80%BC%ED%8C%85%EB%B0%B1/60/'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "thumbnail" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//parisandyou.co.kr/'):
            img_url_list.append(url["src"])
                
while current_page <= 6:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://parisandyou.co.kr/category/%ED%80%BC%ED%8C%85%EB%B0%B1/60/' + '?page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//parisandyou.co.kr/'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)
 

quilt_img_url_list = list(set(img_url_list))

len(quilt_img_url_list)

## 미니/크로스백

print("---------------------------------------------------------------------------")
print("미니백 / 크로스백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 2

img_url_list = []

print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://parisandyou.co.kr/product/list.html?cate_no=61'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "thumbnail" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//parisandyou.co.kr/'):
            img_url_list.append(url["src"])
                
while current_page <= 15:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://parisandyou.co.kr/product/list.html?cate_no=61' + '&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//parisandyou.co.kr/'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

mini_cross_img_url_list = list(set(img_url_list))

len(mini_cross_img_url_list)

## 클러치백

print("---------------------------------------------------------------------------")
print("클러치백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 2

img_url_list = []

print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://parisandyou.co.kr/category/%ED%81%B4%EB%9F%AC%EC%B9%98%EB%B0%B1/47/'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "thumbnail" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//parisandyou.co.kr/'):
            img_url_list.append(url["src"])
                
while current_page <= 7:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://parisandyou.co.kr/category/%ED%81%B4%EB%9F%AC%EC%B9%98%EB%B0%B1/47/' + '?page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//parisandyou.co.kr/'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

clutch_img_url_list = list(set(img_url_list))

len(clutch_img_url_list)

## 천연가죽 (숄더/토트 + 클러치 + 미니/크로스 + 퀼팅백)

# 숄더/토트

print("\n")
print("---------------------------------------------------------------------------")
print("천연가죽 숄더백 / 토트백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")
current_page = 2

natural_list = []
img_url_list = []

print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://parisandyou.co.kr/product/list.html?cate_no=99'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "thumbnail" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//parisandyou.co.kr/'):
            img_url_list.append(url["src"])
                
while current_page <= 12:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://parisandyou.co.kr/product/list.html?cate_no=99' + '&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//parisandyou.co.kr/'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

natural_list = list(set(img_url_list))
new_shoulder_tote_img_url_list = shoulder_tote_img_url_list + natural_list


# 클러치

print("\n")
print("---------------------------------------------------------------------------")
print("천연가죽 클러치백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")
current_page = 2

natural_list = []
img_url_list = []

print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://parisandyou.co.kr/product/list.html?cate_no=101'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "thumbnail" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//parisandyou.co.kr/'):
            img_url_list.append(url["src"])
                
while current_page <= 3:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://parisandyou.co.kr/product/list.html?cate_no=101' + '&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//parisandyou.co.kr/'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

natural_list = list(set(img_url_list))
new_clutch_img_url_list = clutch_img_url_list + natural_list



# 미니/크로스

print("\n")
print("---------------------------------------------------------------------------")
print("천연가죽 미니백 / 크로스백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")
current_page = 2

natural_list = []
img_url_list = []

print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://parisandyou.co.kr/product/list.html?cate_no=102'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "thumbnail" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//parisandyou.co.kr/'):
            img_url_list.append(url["src"])
                
while current_page <= 8:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://parisandyou.co.kr/product/list.html?cate_no=102' + '&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//parisandyou.co.kr/'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

natural_list = list(set(img_url_list))
new_mini_cross_img_url_list = mini_cross_img_url_list + natural_list


# 퀼팅백

print("---------------------------------------------------------------------------")
print("천연가죽 퀼팅백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")
current_page = 2

img_url_list = []

print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://parisandyou.co.kr/product/list.html?cate_no=127'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "thumbnail" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//parisandyou.co.kr/'):
            img_url_list.append(url["src"])
                
while current_page <= 2:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://parisandyou.co.kr/product/list.html?cate_no=127' + '&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//parisandyou.co.kr/'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

natural_list = list(set(img_url_list))
new_quilt_img_url_list = quilt_img_url_list + natural_list


len(new_shoulder_tote_img_url_list)

new_shoulder_tote_img_url_list = list(set(new_shoulder_tote_img_url_list))
new_quilt_img_url_list = list(set(new_quilt_img_url_list))
new_mini_cross_img_url_list = list(set(new_mini_cross_img_url_list))
new_clutch_img_url_list = list(set(new_clutch_img_url_list))

## 인조가죽 (숄더/토트 + 클러치 + 미니/크로스 + 퀼팅백)

# 숄더/토트

print("\n")
print("---------------------------------------------------------------------------")
print("인조가죽 숄더백 / 토트백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")
current_page = 2

artificial_list = []
img_url_list = []

print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://parisandyou.co.kr/product/list.html?cate_no=103'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "thumbnail" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//parisandyou.co.kr/'):
            img_url_list.append(url["src"])
                
while current_page <= 19:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://parisandyou.co.kr/product/list.html?cate_no=103' + '&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//parisandyou.co.kr/'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

artificial_list = list(set(img_url_list))
final_shoulder_tote_img_url_list = new_shoulder_tote_img_url_list + artificial_list


# 클러치

print("\n")
print("---------------------------------------------------------------------------")
print("인조가죽 클러치백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")
current_page = 2

artificial_list = []
img_url_list = []

print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://parisandyou.co.kr/product/list.html?cate_no=105'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "thumbnail" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//parisandyou.co.kr/'):
            img_url_list.append(url["src"])
                
while current_page <= 4:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://parisandyou.co.kr/product/list.html?cate_no=105' + '&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//parisandyou.co.kr/'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

artificial_list = list(set(img_url_list))
final_clutch_img_url_list = new_clutch_img_url_list + artificial_list



# 미니/크로스

print("\n")
print("---------------------------------------------------------------------------")
print("인조가죽 미니백 / 크로스백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")
current_page = 2

artificial_list = []
img_url_list = []

print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://parisandyou.co.kr/product/list.html?cate_no=106'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "thumbnail" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//parisandyou.co.kr/'):
            img_url_list.append(url["src"])
                
while current_page <= 8:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://parisandyou.co.kr/product/list.html?cate_no=106' + '&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//parisandyou.co.kr/'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

artificial_list = list(set(img_url_list))
final_mini_cross_img_url_list = new_mini_cross_img_url_list + artificial_list


final_shoulder_tote_img_url_list = list(set(final_shoulder_tote_img_url_list))
final_quilt_img_url_list = list(set(new_quilt_img_url_list))
final_mini_cross_img_url_list = list(set(final_mini_cross_img_url_list))
final_clutch_img_url_list = list(set(final_clutch_img_url_list))

len(final_shoulder_tote_img_url_list)

len(final_quilt_img_url_list)

len(final_mini_cross_img_url_list)

len(final_clutch_img_url_list)

pau_img_url_list = final_shoulder_tote_img_url_list + final_quilt_img_url_list + final_mini_cross_img_url_list + final_clutch_img_url_list

len(pau_img_url_list)

pau_img_url_list

## Write to csv file

import csv
import pandas as pd

with open('PAU_all_bag.csv', 'w', newline='') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(pau_img_url_list)
# with open('pau_shoulderder_tote.csv', 'w', newline='') as f:
#     writer = csv.writer(f, quoting=csv.QUOTE_ALL)
#     writer.writerow(final_shoulder_tote_img_url_list)
    
# with open('pau_quilt.csv', 'w', newline='') as f:
#     writer = csv.writer(f, quoting=csv.QUOTE_ALL)
#     writer.writerow(final_quilt_img_url_list)

# with open('pau_mini_cross.csv', 'w', newline='') as f:
#     writer = csv.writer(f, quoting=csv.QUOTE_ALL)
#     writer.writerow(final_mini_cross_img_url_list)
    
# with open('pau_clutch.csv', 'w', newline='') as f:
#     writer = csv.writer(f, quoting=csv.QUOTE_ALL)
#     writer.writerow(final_clutch_img_url_list)

# %% [markdown]
# # luzzibag web crawling

# %%
## 숄더백

print("\n")
print("---------------------------------------------------------------------------")
print("숄더백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
shoulder_img_url_list = []
            
while current_page <= 2:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.luzzibag.com/category/%EC%88%84%EB%8D%94%EB%B0%B1/27/' + '?page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "prdImg_thumb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//www.luzzibag.com/web/product/tiny'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

shoulder_img_url_list = img_url_list
                

## 토트백

print("\n")
print("---------------------------------------------------------------------------")
print("토트백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
tote_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://www.luzzibag.com/category/%ED%86%A0%ED%8A%B8%EB%B0%B1/28/'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "prdImg_thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//www.luzzibag.com/web/product/tiny'):
            img_url_list.append(url["src"])
            
tote_img_url_list = img_url_list            

## 쇼퍼백

print("\n")
print("---------------------------------------------------------------------------")
print("쇼퍼백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
shopper_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://www.luzzibag.com/category/%EC%87%BC%ED%8D%BC%EB%B0%B1/64/'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "prdImg_thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//www.luzzibag.com/web/product/tiny'):
            img_url_list.append(url["src"])
            
shopper_img_url_list = img_url_list            

## 크로스백

print("\n")
print("---------------------------------------------------------------------------")
print("크로스백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
cross_img_url_list = []
            
while current_page <= 2:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.luzzibag.com/category/%ED%81%AC%EB%A1%9C%EC%8A%A4%EB%B0%B1/29/' + '?page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "prdImg_thumb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//www.luzzibag.com/web/product/tiny'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

cross_img_url_list = img_url_list

## 힙색/클러치백

print("\n")
print("---------------------------------------------------------------------------")
print("쇼퍼백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
clutch_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://www.luzzibag.com/category/%ED%9E%99%EC%83%89%ED%81%B4%EB%9F%AC%EC%B9%98%EB%B0%B1/30/'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "prdImg_thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//www.luzzibag.com/web/product/tiny'):
            img_url_list.append(url["src"])
            
clutch_img_url_list = img_url_list            

## 겹치는 image 발견해서 삭제하기 

total_img_url_list = shoulder_img_url_list + tote_img_url_list + shopper_img_url_list + clutch_img_url_list + cross_img_url_list

total_img_url_list

len(total_img_url_list)

total_img_url_list = list(set(total_img_url_list))

len(total_img_url_list)

## Write to csv file 

import csv

with open('Luzzi_all_bag.csv', 'w', newline='') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(total_img_url_list)

## 잘 들어갔는지 확인하기 

import pandas as pd

df = pd.read_csv('Luzzi_all_bag.csv')

df

# %% [markdown]
# # JADE BAG web crawling

# %%
## 숄더백

print("\n")
print("---------------------------------------------------------------------------")
print("숄더백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
shoulder_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://www.jadebag.co.kr/shop/shopbrand.html?xcode=004&type=X'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('dt', {"class" : "thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('/shopimages'):
            img_url_list.append("www.jadebag.co.kr" + url["src"])
            
shoulder_img_url_list = img_url_list            

shoulder_img_url_list

## 토트/크로스백

print("\n")
print("---------------------------------------------------------------------------")
print("토트/크로스백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
tote_cross_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://www.jadebag.co.kr/shop/shopbrand.html?xcode=006&type=X'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('dt', {"class" : "thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('/shopimages'):
            img_url_list.append("www.jadebag.co.kr" + url["src"])
            
tote_cross_img_url_list = img_url_list            

tote_cross_img_url_list

## 트렌드백

print("\n")
print("---------------------------------------------------------------------------")
print("트렌드백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
trend_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://www.jadebag.co.kr/shop/shopbrand.html?xcode=007&type=O'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('dt', {"class" : "thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('/shopimages'):
            img_url_list.append("www.jadebag.co.kr" + url["src"])
            
trend_img_url_list = img_url_list            

trend_img_url_list

## 클러치/지갑

print("\n")
print("---------------------------------------------------------------------------")
print("클러치백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
clutch_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://www.jadebag.co.kr/shop/shopbrand.html?xcode=014&type=P'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('dt', {"class" : "thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('/shopimages'):
            img_url_list.append("www.jadebag.co.kr" + url["src"])
            
clutch_img_url_list = img_url_list            

clutch_img_url_list

## 세일

print("\n")
print("---------------------------------------------------------------------------")
print("세일백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
sale_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://www.jadebag.co.kr/shop/shopbrand.html?xcode=016&type=P'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('dt', {"class" : "thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('/shopimages'):
            img_url_list.append("www.jadebag.co.kr" + url["src"])
            
sale_img_url_list = img_url_list            

sale_img_url_list

## The VAN

print("\n")
print("---------------------------------------------------------------------------")
print("더 밴? 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
van_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://www.jadebag.co.kr/shop/shopbrand.html?xcode=009&type=X'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('dt', {"class" : "thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('/shopimages'):
            img_url_list.append("www.jadebag.co.kr" + url["src"])
            
van_img_url_list = img_url_list            

van_img_url_list

## IT bag

print("\n")
print("---------------------------------------------------------------------------")
print("IT 백사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
IT_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'http://www.jadebag.co.kr/shop/shopbrand.html?xcode=002&type=X'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('dt', {"class" : "thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('/shopimages'):
            img_url_list.append("www.jadebag.co.kr" + url["src"])
            
IT_img_url_list = img_url_list            

IT_img_url_list

jade_total_img_url_list = IT_img_url_list + van_img_url_list + shoulder_img_url_list + tote_cross_img_url_list + trend_img_url_list + clutch_img_url_list + sale_img_url_list

jade_total_img_url_list = list(set(jade_total_img_url_list))

len(jade_total_img_url_list)

## Write to csv file

import csv

with open('jade_all_bag.csv', 'w', newline='') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(jade_total_img_url_list)

# %% [markdown]
# # M-jade web crawling

# %%
## 토트백

print("\n")
print("---------------------------------------------------------------------------")
print("토트백 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
tote_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'https://www.m-jade.co.kr/product/list.html?cate_no=135'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "sp-product-item-thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//www.m-jade.co.kr/web/product'):
            img_url_list.append(url["src"])
            
tote_img_url_list = img_url_list            

tote_img_url_list

## 숄더백

print("\n")
print("---------------------------------------------------------------------------")
print("숄더백 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
shoulder_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'https://www.m-jade.co.kr/product/list.html?cate_no=137'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "sp-product-item-thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//www.m-jade.co.kr/web/product'):
            img_url_list.append(url["src"])
            
shoulder_img_url_list = img_url_list            

shoulder_img_url_list

## 미니백

print("\n")
print("---------------------------------------------------------------------------")
print("미니백 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

img_url_list = []
mini_img_url_list = []
            
print("1번째 페이지 이미지를 다운로드 중입니다!")
url = 'https://www.m-jade.co.kr/product/list.html?cate_no=136'
web = urlopen(url)
source = BeautifulSoup(web, 'html.parser')
for a in source.find_all('div', {"class" : "sp-product-item-thumb" }):
    for url in a.find_all("img"):
        if url["src"].startswith('//www.m-jade.co.kr/web/product'):
            img_url_list.append(url["src"])
            
mini_img_url_list = img_url_list            

mini_img_url_list

MJADE_total_bag = mini_img_url_list + shoulder_img_url_list + tote_img_url_list

MJADE_total_bag = list(set(MJADE_total_bag))

len(MJADE_total_bag)

## Write to csv file

import csv

with open('mjade_all_bag.csv', 'w', newline='') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(MJADE_total_bag)

# %% [markdown]
# # GABANGPOP web crawling

# %%
## 크로스백

print("---------------------------------------------------------------------------")
print("크로스백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
cross_list = []

while current_page <= 12:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.gabangpop.co.kr/app/category/lists/130002/?category=&d_cat_cd=130002&brand=&sort=pop&display_cnt=100' + '&page=' + str(current_page) + '&page_kind=category&list_kind=small&free_dlv=&sale_goods=&popup=&b_idx=&=100'
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('a', {"class" : "td_a" }):
        for url in a.find_all("img"):
            if url["src"].startswith('http://cimg.gabangpop.co.kr/images'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

cross_list = img_url_list

cross_list

len(cross_list)

## 숄더/쇼퍼백

print("---------------------------------------------------------------------------")
print("숄더/쇼퍼백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
shoulder_shopper_list = []

while current_page <= 9:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.gabangpop.co.kr/app/category/lists/130003/?category=&d_cat_cd=130003&brand=&sort=pop&display_cnt=100' + '&page=' + str(current_page) + '&page_kind=category&list_kind=small&free_dlv=&sale_goods=&popup=&b_idx=100'
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('a', {"class" : "td_a" }):
        for url in a.find_all("img"):
            if url["src"].startswith('http://cimg.gabangpop.co.kr/images'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

shoulder_shopper_list = img_url_list

shoulder_shopper_list

len(shoulder_shopper_list)

## 토트백

print("---------------------------------------------------------------------------")
print("토트백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
tote_list = []

while current_page <= 7:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.gabangpop.co.kr/app/category/lists/130004/?category=&d_cat_cd=130004&brand=&sort=pop&display_cnt=100' + '&page=' + str(current_page) + '&page_kind=category&list_kind=small&free_dlv=&sale_goods=&popup=&b_idx=100'
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('a', {"class" : "td_a" }):
        for url in a.find_all("img"):
            if url["src"].startswith('http://cimg.gabangpop.co.kr/images'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

tote_list = img_url_list

tote_list

len(tote_list)

## 버킷백

print("---------------------------------------------------------------------------")
print("버킷백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
bucket_list = []

while current_page <= 1:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.gabangpop.co.kr/app/category/lists/130005/?category=&d_cat_cd=130005&brand=&sort=pop&display_cnt=100' + '&page=' + str(current_page) + '&page_kind=category&list_kind=small&free_dlv=&sale_goods=&popup=&b_idx=100'
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('a', {"class" : "td_a" }):
        for url in a.find_all("img"):
            if url["src"].startswith('http://cimg.gabangpop.co.kr/images'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

bucket_list = img_url_list

bucket_list

len(bucket_list)

## 사첼백 

print("---------------------------------------------------------------------------")
print("사첼백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
sachel_list = []

while current_page <= 1:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.gabangpop.co.kr/app/category/lists/130006'
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('a', {"class" : "td_a" }):
        for url in a.find_all("img"):
            if url["src"].startswith('http://cimg.gabangpop.co.kr/images'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

sachel_list = img_url_list

sachel_list

len(sachel_list)

## 미니백

print("---------------------------------------------------------------------------")
print("미니백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
mini_list = []

while current_page <= 4:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.gabangpop.co.kr/app/category/lists/130007/?category=&d_cat_cd=130007&brand=&sort=pop&display_cnt=100' + '&page=' + str(current_page) + '&page_kind=category&list_kind=small&free_dlv=&sale_goods=&popup=&b_idx=100'
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('a', {"class" : "td_a" }):
        for url in a.find_all("img"):
            if url["src"].startswith('http://cimg.gabangpop.co.kr/images'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

mini_list = img_url_list

mini_list

len(mini_list)

## 에코백

print("---------------------------------------------------------------------------")
print("에코백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
eco_list = []

while current_page <= 6:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.gabangpop.co.kr/app/category/lists/130008/?category=&d_cat_cd=130008&brand=&sort=pop&display_cnt=100' + '&page=' + str(current_page) + '&page_kind=category&list_kind=small&free_dlv=&sale_goods=&popup=&b_idx=100'
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('a', {"class" : "td_a" }):
        for url in a.find_all("img"):
            if url["src"].startswith('http://cimg.gabangpop.co.kr/images'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

eco_list = img_url_list

eco_list

len(eco_list)

## 클러치백

print("---------------------------------------------------------------------------")
print("클러치백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
clutch_list = []

while current_page <= 3:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.gabangpop.co.kr/app/category/lists/130009/?category=&d_cat_cd=130009&brand=&sort=pop&display_cnt=100' + '&page=' + str(current_page) + '&page_kind=category&list_kind=small&free_dlv=&sale_goods=&popup=&b_idx=100'
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('a', {"class" : "td_a" }):
        for url in a.find_all("img"):
            if url["src"].startswith('http://cimg.gabangpop.co.kr/images'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

clutch_list = img_url_list

clutch_list

len(clutch_list)

## 전체 합치기 (중복 제거)

gabangpop_list = clutch_list + eco_list + mini_list + sachel_list + bucket_list + tote_list + shoulder_shopper_list + cross_list

len(gabangpop_list)

gabangpop_list = list(set(gabangpop_list))

len(gabangpop_list)

## Write to csv file 

import csv

with open('./bag_image_url/gabangpop_all_bag.csv', 'w', newline='') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(gabangpop_list)

# %% [markdown]
# # McLANEE web crawling

# %%
## 토트백

print("---------------------------------------------------------------------------")
print("토트백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
tote_list = []

while current_page <= 7:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.mclanee.co.kr/product/list.html?cate_no=24&page=' + str(current_page) 
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "prd_tmb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//www.mclanee.co.kr/web/product'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

tote_list = img_url_list

tote_list 

len(tote_list)

## 숄더백

print("---------------------------------------------------------------------------")
print("숄더백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
shoulder_list = []

while current_page <= 3:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.mclanee.co.kr/product/list.html?cate_no=27&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "prd_tmb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//www.mclanee.co.kr/web/product'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

shoulder_list = img_url_list

shoulder_list

len(shoulder_list)

## 미니/크로스백

print("---------------------------------------------------------------------------")
print("미니크로스백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
mini_cross_list = []

while current_page <= 8:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.mclanee.co.kr/product/list.html?cate_no=25&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "prd_tmb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//www.mclanee.co.kr/web/product'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

mini_cross_list = img_url_list

mini_cross_list

len(mini_cross_list)

## 클러치백

print("---------------------------------------------------------------------------")
print("클러치백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
clutch_list = []

while current_page <= 1:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.mclanee.co.kr/product/list.html?cate_no=72&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "prd_tmb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//www.mclanee.co.kr/web/product'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

clutch_list = img_url_list

clutch_list

len(clutch_list)

## 전체 합치기 (중복 제거)

mclanee_list = clutch_list + mini_cross_list + shoulder_list + tote_list

mclanee_list = list(set(mclanee_list))

len(mclanee_list)

## Write to csv file

import csv

with open('./bag_image_url/mclanee_all_bag.csv', 'w', newline='') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(mclanee_list)

# %% [markdown]
# # Whosbag web crawling

# %%
## IT BAG

print("---------------------------------------------------------------------------")
print("IT백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
IT_list = []

while current_page <= 2:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.whosbag.com/shop/shopbrand.html?type=X&xcode=007&sort=&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "item_list" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/whosbag'):
                img_url_list.append('www.whosbag.com' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

IT_list = img_url_list

IT_list

len(IT_list)

## 가죽 가방

print("---------------------------------------------------------------------------")
print("가죽백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
leather_list = []

while current_page <= 3:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.whosbag.com/shop/shopbrand.html?type=X&xcode=027&sort=&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "item_list" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/whosbag'):
                img_url_list.append('www.whosbag.com' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

leather_list = img_url_list

leather_list

len(leather_list)

print("---------------------------------------------------------------------------")
print("IT백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
IT_list = []

while current_page <= 2:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.whosbag.com/shop/shopbrand.html?type=X&xcode=007&sort=&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "item_list" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/whosbag'):
                img_url_list.append('www.whosbag.com' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

IT_list = img_url_list

IT_list

len(IT_list)

## 가죽 가방

print("---------------------------------------------------------------------------")
print("가죽백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
leather_list = []

while current_page <= 3:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.whosbag.com/shop/shopbrand.html?type=X&xcode=027&sort=&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "item_list" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/whosbag'):
                img_url_list.append('www.whosbag.com' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

leather_list = img_url_list

leather_list

len(leather_list)

len(leather_list)

## 트렌드백

print("---------------------------------------------------------------------------")
print("트렌드백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
trend_list = []

while current_page <= 10:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.whosbag.com/shop/shopbrand.html?type=X&xcode=014&sort=&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "item_list" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/whosbag'):
                img_url_list.append('www.whosbag.com' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

trend_list = img_url_list

trend_list

len(trend_list)

## 클러치백

print("---------------------------------------------------------------------------")
print("클러치백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
clutch_list = []

while current_page <= 2:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.whosbag.com/shop/shopbrand.html?type=X&xcode=002&sort=&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "item_list" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/whosbag'):
                img_url_list.append('www.whosbag.com' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

clutch_list = img_url_list

clutch_list

len(clutch_list)

## 전체 합치기 (중복 제거)

whosbag_list = clutch_list + trend_list + leather_list + IT_list

len(whosbag_list)

whosbag_list = list(set(whosbag_list))

len(whosbag_list)

## Write to csv file

import csv

with open('./bag_image_url/whosbag_all_bag.csv', 'w', newline='') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(whosbag_list)

# %% [markdown]
# # bagshoes web crawling

# %%
## Motor bag

print("---------------------------------------------------------------------------")
print("모터백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
motor_list = []

while current_page <= 1:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.bagshoes.co.kr/shop/shopbrand.html?xcode=048&type=X' 
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "prd-thumb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/yhseolyn'):
                img_url_list.append('www.bagshoes.co.kr' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)
    
motor_list = img_url_list

motor_list

len(motor_list)

## leather bag

print("---------------------------------------------------------------------------")
print("레더백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
leather_list = []

while current_page <= 1:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.bagshoes.co.kr/shop/shopbrand.html?xcode=038&type=X' 
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "prd-thumb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/yhseolyn'):
                img_url_list.append('www.bagshoes.co.kr' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)
    
leather_list = img_url_list

leather_list

len(leather_list)

## trend bag

print("---------------------------------------------------------------------------")
print("트렌드백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
trend_list = []

while current_page <= 4:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.bagshoes.co.kr/shop/shopbrand.html?type=X&xcode=020&sort=&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "prd-thumb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/yhseolyn'):
                img_url_list.append('www.bagshoes.co.kr' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)
    
trend_list = img_url_list

trend_list

len(trend_list)

## shopper_shoulder bag

print("---------------------------------------------------------------------------")
print("쇼퍼/숄더백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
shopper_shoulder_list = []

while current_page <= 1:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.bagshoes.co.kr/shop/shopbrand.html?xcode=006&type=P'
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "prd-thumb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/yhseolyn'):
                img_url_list.append('www.bagshoes.co.kr' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)
    
shopper_shoulder_list = img_url_list

shopper_shoulder_list

len(shopper_shoulder_list)

## 전체 합치기 (중복 제거)

bagshoes_list = shopper_shoulder_list + trend_list + leather_list + motor_list

bagshoes_list = list(set(bagshoes_list))

len(bagshoes_list)

## Wirte to csv file

import csv 

with open('./bag_image_url/bagshoes_all_bag.csv', 'w', newline='') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(bagshoes_list)

## 혹시 모르니까 확인해보기 

import pandas as pd

df = pd.read_csv('./bag_image_url/bagshoes_all_bag.csv')

df
# Out:
# ---------------------------------------------------------------------------
# 모터백 사진 url 다운로드를 시작합니다
# ---------------------------------------------------------------------------
#
#
# 1번째 페이지 이미지를 다운로드 중입니다!

# %% [markdown]
# # pinkbag web crawling

# %%
# leather bag

print("---------------------------------------------------------------------------")
print("레더백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
leather_list = []

while current_page <= 1:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.pinkbag.co.kr/product/list.html?cate_no=44&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//www.pinkbag.co.kr/web/product'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)
    
leather_list = img_url_list

leather_list

len(leather_list)

# 인공 leather bag

print("---------------------------------------------------------------------------")
print("레더백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
artificial_leather_list = []

while current_page <= 3:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.pinkbag.co.kr/product/list.html?cate_no=45&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//www.pinkbag.co.kr/web/product'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)
    
artificial_leather_list = img_url_list

artificial_leather_list

len(artificial_leather_list)

# mini bag

print("---------------------------------------------------------------------------")
print("mini백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
mini_list = []

while current_page <= 1:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.pinkbag.co.kr/product/list.html?cate_no=52' 
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "thumbnail" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//www.pinkbag.co.kr/web/product'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)
    
mini_list = img_url_list

mini_list

len(mini_list)

## 전체 합치기 (중복 제거)

pinkbag_list = mini_list + artificial_leather_list + leather_list

pinkbag_list = list(set(pinkbag_list))

len(pinkbag_list)

## Write to csv file 

import csv 

with open('./bag_image_url/pinkbag_all_bag.csv', 'w', newline='') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(pinkbag_list)
# Out:
# ---------------------------------------------------------------------------
# 레더백 사진 url 다운로드를 시작합니다
# ---------------------------------------------------------------------------
#
#
# 1번째 페이지 이미지를 다운로드 중입니다!

# %% [markdown]
# # CAMEL BRWON web crawling

# %%
# TODO : html gif url -> jpg url
# gif to jpg python code 

import PIL
from PIL import Image
import sys

def processImage(infile):
    try:
        im = Image.open(infile)
    except IOError:
        print('Cant load')
        sys.exit(1)
    i = 0
    mypalette = im.getpalette()

    try:
        while 1:
            im.putpalette(mypalette)
            new_im = Image.new("RGB", im.size)
            new_im.paste(im)
            new_im.save('foo'+str(i)+'.jpg')

            i += 1
            im.seek(im.tell() + 1)

    except EOFError:
        pass # end of sequence

processImage('example.gif')

# %% [markdown]
# # comingbag web crawling

# %%
print("---------------------------------------------------------------------------")
print("모든백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
all_list = []

while current_page <= 4:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.comingbag.co.kr/product/list.html?cate_no=82&page=' + str(current_page) + '#none' 
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "box" }):
        for url in a.find_all("img"):
            if url["src"].startswith('//www.comingbag.co.kr/web/product'):
                img_url_list.append(url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

all_list = img_url_list

all_list

len(all_list)

## Write to csv file 

import csv

with open('./bag_image_url/comingbag_all_bag.csv', 'w', newline='') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(all_list)
# Out:
# ---------------------------------------------------------------------------
# 모든백 사진 url 다운로드를 시작합니다
# ---------------------------------------------------------------------------
#
#
# 1번째 페이지 이미지를 다운로드 중입니다!
# 2번째 페이지 이미지를 다운로드 중입니다!
# 3번째 페이지 이미지를 다운로드 중입니다!
# 4번째 페이지 이미지를 다운로드 중입니다!

# %% [markdown]
# # bnburde web crawling

# %%
## 가죽백 

print("---------------------------------------------------------------------------")
print("가죽백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
leather_list = []

while current_page <= 4:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.bnburde.com/shop/shopbrand.html?type=Y&xcode=018&sort=&page=' + str(current_page) 
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('dt', {"class" : "thumb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/bnburde'):
                img_url_list.append('www.bnburde.com' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

leather_list = img_url_list

leather_list 

len(leather_list)

## 토트백

print("---------------------------------------------------------------------------")
print("토트백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
tote_list = []

while current_page <= 2:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.bnburde.com/shop/shopbrand.html?type=X&xcode=001&sort=&page=' + str(current_page) 
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('dt', {"class" : "thumb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/bnburde'):
                img_url_list.append('www.bnburde.com' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

tote_list = img_url_list

tote_list

len(tote_list)

## 숄더백 

print("---------------------------------------------------------------------------")
print("숄더백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
shoulder_list = []

while current_page <= 2:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.bnburde.com/shop/shopbrand.html?type=X&xcode=002&sort=&page=' + str(current_page) 
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('dt', {"class" : "thumb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/bnburde'):
                img_url_list.append('www.bnburde.com' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

shoulder_list = img_url_list

shoulder_list

len(shoulder_list)

## 크로스백

print("---------------------------------------------------------------------------")
print("크로스백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
cross_list = []

while current_page <= 3:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.bnburde.com/shop/shopbrand.html?type=X&xcode=003&sort=&page=' + str(current_page) 
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('dt', {"class" : "thumb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/bnburde'):
                img_url_list.append('www.bnburde.com' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

cross_list = img_url_list

cross_list

len(cross_list)

## 클러치백

print("---------------------------------------------------------------------------")
print("클러치백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
clutch_list = []

while current_page <= 1:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.bnburde.com/shop/shopbrand.html?type=X&xcode=004'
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('dt', {"class" : "thumb" }):
        for url in a.find_all("img"):
            if url["src"].startswith('/shopimages/bnburde'):
                img_url_list.append('www.bnburde.com' + url["src"])
                
    current_page = current_page + 1            
    time.sleep(5)

clutch_list = img_url_list

clutch_list

len(clutch_list)

## 전체 합치기 (중복 제거)

bnburde_list = clutch_list + cross_list + shoulder_list + tote_list + leather_list

bnburde_list = list(set(bnburde_list))

len(bnburde_list)

## Write to csv file 

import csv

with open('./bag_image_url/bnburde_all_bag.csv', 'w', newline='') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(bnburde_list)
# Out:
# ---------------------------------------------------------------------------
# 가죽백 사진 url 다운로드를 시작합니다
# ---------------------------------------------------------------------------
#
#
# 1번째 페이지 이미지를 다운로드 중입니다!
# 2번째 페이지 이미지를 다운로드 중입니다!
# 3번째 페이지 이미지를 다운로드 중입니다!
# 4번째 페이지 이미지를 다운로드 중입니다!

# %% [markdown]
# # From BEGINNING web crawling

# %%
## 두 가지 경우에 대해서 해야함 (onmouseover + onmouseout)

print("---------------------------------------------------------------------------")
print("모든백 사진 url 다운로드를 시작합니다")
print("---------------------------------------------------------------------------")
print("\n")

current_page = 1

img_url_list = []
bag_list = []

while current_page <= 3:
    print(str(current_page) + "번째 페이지 이미지를 다운로드 중입니다!")
    url = 'http://www.beginning.kr/shop/shopbrand.html?type=Y&xcode=041&sort=&page=' + str(current_page)
    web = urlopen(url)
    source = BeautifulSoup(web, 'html.parser')
    for a in source.find_all('div', {"class" : "prd-thumb" }):
        for url in a.find_all("img"):
            if url['src'].startswith("/shopimages/beginning1"):
                img_url_list.append('www.beginning.kr' + url["src"])
           
                
    current_page = current_page + 1            
    time.sleep(5)

bag_list = img_url_list

bag_list

len(bag_list)

bag_list = list(set(bag_list))

len(bag_list)

## Wirte to csv file 

import csv

with open('./bag_image_url/beginning_all_bag.csv', 'w', newline='') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(bag_list)
# Out:
# ---------------------------------------------------------------------------
# 모든백 사진 url 다운로드를 시작합니다
# ---------------------------------------------------------------------------
#
#
# 1번째 페이지 이미지를 다운로드 중입니다!
# 2번째 페이지 이미지를 다운로드 중입니다!
# 3번째 페이지 이미지를 다운로드 중입니다!
